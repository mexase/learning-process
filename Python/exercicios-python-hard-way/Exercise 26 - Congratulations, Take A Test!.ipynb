# %%
entry = str(input('Enter a phrase: '))


def break_words(stuff):
    """This function will break up words for us."""
    words = stuff.split(' ')
    print(words)
    return words


def print_sorted_words(words):  # Function renamed to prin_sorted words.
    """Sorts the words."""
    split = words.split(' ')
    sort = sorted(split)
    print(sort)
    return sort


def print_first_word(words):  # Added missing :
    """Prints the first word after popping it off."""
    word = words.pop(0)  # poop? god. Isn't pop?
    print(word)


def print_last_word(words):
    """Prints the last word after popping it off."""
    word = words.pop(-1)  # added ) after -1
    print(word)


def sort_sentence(sentence):
    """Takes in a full sentence and returns the sorted words."""
    words = break_words(sentence)
    return sort_words(words)


def print_first_and_last(sentence):
    """Prints the first and last words of the sentence."""
    word1 = sentence.pop(0)
    word2 = sentence.pop(-1)
    print(word1)
    print(word2)


def print_first_and_last_sorted(sentence):
    """Sorts the words then prints the first and last one."""
    word1 = sentence.pop(0)
    word2 = sentence.pop(-1)
    print(word1)
    print(word2)


print('Lets practice everything.')  # added a \ before ' for a correct let's.
print('You\'d need to know \'bout escapes with \\ that do \n newlines and \t tabs.')

poem = """
\tThe lovely world
with logic so firmly planted
cannot discern \n the needs of love
nor comprehend passion from intuition
and requires an explantion
\n\t\twhere there is none.
"""

print('--------------')
print(poem)
print('--------------')

five = 10 - 2 + 3 - 6  # Change -5 to 6 and the result will be 5.
print('This should be five: %s' % five)


def secret_formula(started):
    jelly_beans = started * 500
    jars = jelly_beans / 1000  # Changed \ for /
    crates = jars / 100
    return jelly_beans, jars, crates


start_point = 10000
beans, jars, crates = secret_formula(start_point)  # Changed start-point to start_point, and crates == to crates =

print('With a starting point of: {}'.format(start_point))
print('We have {} beans, {} jars, and {} crates.'.format(beans, jars, crates))  # Added % after the first d,
# removed the ' after we and turn jeans on beans.

# start_point = start_point / 10  - The code was modified and simplified to work with python 3 this line is useless
# and can be deleted.

print('We can also do that this way:')
print('We have {:.0f} beans, {:.0f} jars, and {:.0f} crates.'.format(beans / 10, jars / 10,
                                                                     crates / 10))  # changed crabapples
# to crates and added a ) after secret formula.


sentence = 'All good things come to those who wait.'  # All god\tthings come to those who weight'''

print('Breaked words: ')
break_words(entry)
print('\n')
print('First word')
print_first_word(break_words(entry))  # . removed before print
print('\n')
print('Last word')
print_last_word(break_words(entry))
print('\n')
print('First and last')
print_first_and_last(break_words(entry))#indentation removed, changed first_a_ to first_and_
print('\n')
print('Sorted words')
sorteddata = print_sorted_words(entry)
print('\n')
print('Print first and last sorted')
print_first_and_last_sorted(sorteddata)
# Out:
# Enter a phrase: All good things come to those who wait
# Lets practice everything.
# You'd need to know 'bout escapes with \ that do
#  newlines and 	 tabs.
# --------------
#
# 	The lovely world
# with logic so firmly planted
# cannot discern
#  the needs of love
# nor comprehend passion from intuition
# and requires an explantion
#
# 		where there is none.
#
# --------------
# This should be five: 5
# With a starting point of: 10000
# We have 5000000 beans, 5000.0 jars, and 50.0 crates.
# We can also do that this way:
# We have 500000 beans, 500 jars, and 5 crates.
# Breaked words:
# ['All', 'good', 'things', 'come', 'to', 'those', 'who', 'wait']
#
#
# First word
# ['All', 'good', 'things', 'come', 'to', 'those', 'who', 'wait']
# All
#
#
# Last word
# ['All', 'good', 'things', 'come', 'to', 'those', 'who', 'wait']
# wait
#
#
# First and last
# ['All', 'good', 'things', 'come', 'to', 'those', 'who', 'wait']
# All
# wait
#
#
# Sorted words
# ...
